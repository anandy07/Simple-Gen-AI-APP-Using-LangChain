# %% [markdown]
# # Simple Gen AI APP Using Langchain

# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
load_dotenv()

# os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
#LangSmith Tracking
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")

# %%
## Data Ingestion--From the Website we need to Scrape the Data
from langchain_community.document_loaders import WebBaseLoader
# Out:
# /var/folders/hx/xvmbpmz108x0wsykj_dk3znw0000gn/T/ipykernel_91101/1570105959.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import WebBaseLoader
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
loader = WebBaseLoader("https://en.wikipedia.org/wiki/Tata_Consultancy_Services")
loader

# %%
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': 'https://en.wikipedia.org/wiki/Tata_Consultancy_Services', 'title': 'Tata Consultancy Services - Wikipedia', 'language': 'en'}, page_content='\n\n\n\nTata Consultancy Services - Wikipedia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJump to content\n\n\n\n\n\n\n\nMain menu\n\n\n\n\n\nMain menu\nmove to sidebar\nhide\n\n\n\n\t\tNavigation\n\t\n\n\nMain pageContentsCurrent eventsRandom articleAbout WikipediaContact us\n\n\n\n\n\n\t\tContribute\n\t\n\n\nHelpLearn to editCommunity portalRecent changesUpload fileSpecial pages\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAppearance\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDonate\n\nCreate account\n\nLog in\n\n\n\n\n\n\n\n\nPersonal tools\n\n\n\n\n\n\nDonate\n\n\nCreate account\n\n\nLog in\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nContents\nmove to sidebar\nhide\n\n\n\n\n(Top)\n\n\n\n\n\n1\nHistory\n\n\n\n\nToggle His
# ...

# %%
## First we Load the data ---> Docs ---> Divide our text into chunks (becuase LLM have Limited Context Size)
## ---> Convert all the Text into Vector --> Using Vector Embedding ---> then after getting all the 
## vector Embedding we store it into Vector Data Base

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size = 1000, chunk_overlap = 200)
text = text_splitter.split_documents(docs)

# %%
text
# Out:
# [Document(metadata={'source': 'https://en.wikipedia.org/wiki/Tata_Consultancy_Services', 'title': 'Tata Consultancy Services - Wikipedia', 'language': 'en'}, page_content='Tata Consultancy Services - Wikipedia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJump to content\n\n\n\n\n\n\n\nMain menu\n\n\n\n\n\nMain menu\nmove to sidebar\nhide\n\n\n\n\t\tNavigation\n\t\n\n\nMain pageContentsCurrent eventsRandom articleAbout WikipediaContact us\n\n\n\n\n\n\t\tContribute\n\t\n\n\nHelpLearn to editCommunity portalRecent changesUpload fileSpecial pages\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAppearance\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDonate\n\nCreate account\n\nLog in\n\n\n\n\n\n\n\n\nPersonal tools\n\n\n\n\n\n\nDonate\n\n\nCreate account\n\n\nLog in\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nContents\nmove to sidebar\nhide\n\n\n\n\n(Top)\n\n\n\n\n\n1\nHistory\n\n\n\n\nToggle History sub
# ...

# %%
# from langchain_openai import OpenAIEmbeddings

# Embeddings = OpenAIEmbeddings()

# %%
from langchain_huggingface import HuggingFaceEmbeddings

Embedding = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# %%
from langchain_community.vectorstores import FAISS

DB = FAISS.from_documents(text,Embedding)

# %%
DB

# %%
## Query from Vector db
query = "ALL about TCS ? ?"
result = DB.similarity_search(query)
result[0].page_content
# Out:
# '↑ TCS News & Events: Press Release: Department of Posts Awards Core System Integrator project to TCS Archived 9 February 2017 at the Wayback Machine. TCS.com. Retrieved 6 December 2013.\n↑ "TCS joins top 10 global IT services companies club". The Times of India. Archived from the original on 11 April 2015. Retrieved 2 July 2015.\n↑ "TCS first Indian company to top Rs 5 lakh crore market cap". Times of India. 24 July 2014. Archived from the original on 5 October 2015. Retrieved 18 September 2014.\n↑ "TCS Crosses Rs.5 Lk Cr Market Cap". Bloomberg TV India. 24 July 2014. Archived from the original on 23 September 2015.\n↑ "TCS ends RIL\'s 23-year run as most profitable firm". Times of India. 20 January 2014. Archived from the original on 21 April 2016. Retrieved 20 January 2015.\n↑ "TCS partners with Aurus to enhance Omnichannel payment solutions with OmniStore". Archived from the original on 20 April 2017. Retrieved 17 January 2017.'
